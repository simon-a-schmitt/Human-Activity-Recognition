# %%
# %pip install  edge-ml
# Out:
# Collecting edge-ml
#   Downloading edge_ml-0.4.0-py3-none-any.whl.metadata (4.9 kB)
# Downloading edge_ml-0.4.0-py3-none-any.whl (7.8 kB)
# Installing collected packages: edge-ml
# Successfully installed edge-ml-0.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install imblearn
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Collecting imbalanced-learn (from imblearn)
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: numpy<3,>=1.24.3 in /opt/conda/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.10.1 in /opt/conda/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (1.14.1)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in /opt/conda/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (1.5.2)
# Collecting sklearn-compat<1,>=0.1 (from imbalanced-learn->imblearn)
#   Downloading sklearn_compat-0.1.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: joblib<2,>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from imbalanced-learn->imblearn) (3.5.0)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
# Downloading sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Installing collected packages: sklearn-compat, imbalanced-learn, imblearn
# Successfully installed imbalanced-learn-0.13.0 imblearn-0.0 sklearn-compat-0.1.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from edgeml import DatasetReceiver
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %%
# Load project object
project=DatasetReceiver("https://beta.edge-ml.org","02a4fad735d3308b68672ddb7593f047")
project.loadData()

# %%
# Store project object
pickle.dump(project, open("data_snapshot/project_css25.pkl","wb"))
project=pickle.load(open("data_snapshot/project_css25.pkl","rb"))

# %%
# Aggregation_list
filtered_dataframes = []

for d in project.datasets:

    # Only keep datasets with certain length
    if( (d.name == 'devicemotion') & (d.data.shape[0] > 0) & (d.timeSeries[0].end - d.timeSeries[0].start > 10000) ):
        
        # Remove noisy data at beginning and ending of recording
        cleaned_data = d.data.iloc[40:-40].dropna()

        # Add metadata columns
        enriched_data = cleaned_data.assign(**d.metaData)

        # Append to aggregation list
        filtered_dataframes.append(enriched_data)

# Concatenate individual dataframes
df_raw = pd.concat(filtered_dataframes)

# %%
df_raw
# Out:
#                         time  acceleration.x  acceleration.y  acceleration.z  \
# 40   2025-06-03 12:01:23.600             0.0             0.0            -0.2
# 41   2025-06-03 12:01:23.616             0.0             0.0            -0.1
# 42   2025-06-03 12:01:23.632            -0.1             0.0            -0.1
# 43   2025-06-03 12:01:23.649            -0.1             0.1             0.0
# 44   2025-06-03 12:01:23.666            -0.1             0.0             0.1
# ...                      ...             ...             ...             ...
# 1618 2025-07-07 14:36:19.243            -0.1             0.0             0.6
# 1619 2025-07-07 14:36:19.260            -0.1            -0.1             0.4
# 1620 2025-07-07 14:36:19.277            -0.2             0.0             0.1
# 1621 2025-07-07 14:36:19.293            -0.1             0.0             0.0
# 1622 2025-07-07 14:36:19.310             0.1             0.0             0.1
#
#       accelerationIncludingGravity.x  accelerationIncludingGravity.y  \
# 40                              -0.7                             8.5
# 41                              -0.7                             8.5
# 42                              -0.7                             8.6
# 43                              -0.8                             8.5
# 44                              -0.8                             8.5
# ...                              ...                             ...
# 1618                             0.3                             5.2
# 1619                             0.3                             5.2
# 1620                             0.4                             5.3
# 1621                             0.7                             5.4
# 1622                             1.1                             5.4
#
#       accelerationIncludingGravity.z  rotationRate.alpha  rotationRate.beta  \
# 40                               4.9                 2.3           0.100000
# 41                               4.9                 0.8          -0.400000
# 42                               5.0                -0.9          -1.100000
# 43                               5.1                -2.4          -1.400000
# 44                               5.1                -2.4          -1.400000
# ...                              ...                 ...                ...
# 1618                             8.7                14.4         -21.900000
# 1619                             8.4                16.5         -25.100000
# 1620                             8.2                17.6         -26.200001
# 1621                             8.2                19.1         -26.799999
# 1622                             8.4                21.9         -25.400000
#
#       rotationRate.gamma  activity participantId        mobile browser
# 40             -0.900000   sitting         10d83  UnknownPhone  Chrome
# 41             -0.900000   sitting         10d83  UnknownPhone  Chrome
# 42             -0.700000   sitting         10d83  UnknownPhone  Chrome
# 43              0.400000   sitting         10d83  UnknownPhone  Chrome
# 44              0.400000   sitting         10d83  UnknownPhone  Chrome
# ...                  ...       ...           ...           ...     ...
# 1618           15.200000  standing         152a7  UnknownPhone  Chrome
# 1619           16.500000  standing         152a7  UnknownPhone  Chrome
# 1620           17.200001  standing         152a7  UnknownPhone  Chrome
# 1621           15.600000  standing         152a7  UnknownPhone  Chrome
# 1622           13.000000  standing         152a7  UnknownPhone  Chrome
#
# [129591 rows x 14 columns]

# %%
# Drop testing data
df_filtered = df_raw[df_raw['activity'] != 'testing']

# Drop column mobile, Dummy encoding for column browser
df_encoded = pd.concat([df_filtered.drop(columns=["mobile","browser"]),pd.get_dummies(df_filtered[["browser"]])], axis=1)

# Encode activity as integer
df_encoded["activity"], labels = df_encoded["activity"].factorize()

# Set time as index
df_encoded_2 = df_encoded.set_index('time')

# %% [markdown]
# Hier evtl. noch weitere Standard-Features ergänzen

# %%
df_encoded_2['acceleration.magnitude'] = np.sqrt( df_encoded_2['acceleration.x']**2 + df_encoded_2['acceleration.y']**2 + df_encoded_2['acceleration.z']**2 )

# %%
# Create custom mode function that returns only mode value (if there are multiple only the first one is returned)
def mode(x): 
    return (x.mode()[0])

def rms(x):
    return np.sqrt(np.mean(x**2))

# Create aggregation dictionary for groupby which defines aggregation for every column based on datatype
aggs={ 
      **dict.fromkeys(df_encoded_2.select_dtypes(exclude=[np.float32]).columns, [ mode ]),
      **dict.fromkeys(df_encoded_2.select_dtypes(include=[np.float32]).columns, ["mean","var","min","max","median", "skew", "kurt", rms]),

        # Overwrite ealier entry for acitivity -> special treatment
      "activity": [mode,'count'],
}

# Do not consider for aggregation
del(aggs["participantId"])
aggs
# Out:
# {'activity': [<function __main__.mode(x)>, 'count'],
#  'browser_Chrome': [<function __main__.mode(x)>],
#  'browser_Safari': [<function __main__.mode(x)>],
#  'acceleration.x': ['mean',
#   'var',
#   'min',
#   'max',
#   'median',
#   'skew',
#   'kurt',
#   <function __main__.rms(x)>],
#  'acceleration.y': ['mean',
#   'var',
#   'min',
#   'max',
#   'median',
#   'skew',
#   'kurt',
#   <function __main__.rms(x)>],
#  'acceleration.z': ['mean',
#   'var',
#   'min',
#   'max',
#   'median',
#   'skew',
#   'kurt',
#   <function __main__.rms(x)>],
#  'accelerationIncludingGravity.x': ['mean',
#   'var',
#   'min',
#   'max',
#   'median',
#   'skew',
#   'kurt',
#   <function __main__.rms(x)>],
#  'accelerationIncludingGravity.y': ['mean',
#   'var',
#   'min',
#   'max',
#   'median',
#   'skew',
#   'kurt',
#   <function __main__.rms(x)>],
#  'accelerationIncludingGravity.z': ['mean',
#   'var',
#   'min',
#   'max',
#   'median',
#   'skew',
#   'kurt',
#   <function __main__.rms(x)>],
#  'rotationRate.alpha': ['mean',
#   'var',
#   'min',
#   'max',
#   'median',
#   'skew',
#   'kurt',
#   <function __main__.rms(x)>],
#  'rotationRate.beta': ['mean',
#   'var',
#   'min',
#   'max',
#   'median',
#   'skew',
#   'kurt',
#   <function __main__.rms(x)>],
#  'rotationRate.gamma': ['mean',
#   'var',
#   'min',
#   'max',
#   'median',
#   'skew',
#   'kurt',
#   <function __main__.rms(x)>],
#  'acceleration.magnitude': ['mean',
#   'var',
#   'min',
#   'max',
#   'median',
#   'skew',
#   'kurt',
#   <function __main__.rms(x)>]}

# %%
df_encoded_3 = df_encoded_2.groupby("participantId").rolling("1s").agg(aggs)
df_encoded_3.columns = [col[0] + "_" + col[1] if col [1] != "mode" else col[0] for col in df_encoded_3.columns]
df_encoded_3
# Out:
#                                        activity  activity_count  \
# participantId time
# 10d83         2025-06-03 12:01:23.600       0.0             1.0
#               2025-06-03 12:01:23.616       0.0             2.0
#               2025-06-03 12:01:23.632       0.0             3.0
#               2025-06-03 12:01:23.649       0.0             4.0
#               2025-06-03 12:01:23.666       0.0             5.0
# ...                                         ...             ...
# uspgb         2025-06-23 20:26:23.914       0.0            60.0
#               2025-06-23 20:26:23.930       0.0            61.0
#               2025-06-23 20:26:23.947       0.0            60.0
#               2025-06-23 20:26:23.964       0.0            60.0
#               2025-06-23 20:26:23.980       0.0            61.0
#
#                                        browser_Chrome  browser_Safari  \
# participantId time
# 10d83         2025-06-03 12:01:23.600             1.0             0.0
#               2025-06-03 12:01:23.616             1.0             0.0
#               2025-06-03 12:01:23.632             1.0             0.0
#               2025-06-03 12:01:23.649             1.0             0.0
#               2025-06-03 12:01:23.666             1.0             0.0
# ...                                               ...             ...
# uspgb         2025-06-23 20:26:23.914             1.0             0.0
#               2025-06-23 20:26:23.930             1.0             0.0
#               2025-06-23 20:26:23.947             1.0             0.0
#               2025-06-23 20:26:23.964             1.0             0.0
#               2025-06-23 20:26:23.980             1.0             0.0
#
#                                        acceleration.x_mean  \
# participantId time
# 10d83         2025-06-03 12:01:23.600             0.000000
#               2025-06-03 12:01:23.616             0.000000
#               2025-06-03 12:01:23.632            -0.033333
#               2025-06-03 12:01:23.649            -0.050000
#               2025-06-03 12:01:23.666            -0.060000
# ...                                                    ...
# uspgb         2025-06-23 20:26:23.914             0.000000
#               2025-06-23 20:26:23.930             0.000000
#               2025-06-23 20:26:23.947             0.000000
#               2025-06-23 20:26:23.964             0.000000
#               2025-06-23 20:26:23.980             0.000000
#
#                                        acceleration.x_var  acceleration.x_min  \
# participantId time
# 10d83         2025-06-03 12:01:23.600                 NaN                 0.0
#               2025-06-03 12:01:23.616            0.000000                 0.0
#               2025-06-03 12:01:23.632            0.003333                -0.1
#               2025-06-03 12:01:23.649            0.003333                -0.1
#               2025-06-03 12:01:23.666            0.003000                -0.1
# ...                                                   ...                 ...
# uspgb         2025-06-23 20:26:23.914            0.000000                 0.0
#               2025-06-23 20:26:23.930            0.000000                 0.0
#               2025-06-23 20:26:23.947            0.000000                 0.0
#               2025-06-23 20:26:23.964            0.000000                 0.0
#               2025-06-23 20:26:23.980            0.000000                 0.0
#
#                                        acceleration.x_max  \
# participantId time
# 10d83         2025-06-03 12:01:23.600                 0.0
#               2025-06-03 12:01:23.616                 0.0
#               2025-06-03 12:01:23.632                 0.0
#               2025-06-03 12:01:23.649                 0.0
#               2025-06-03 12:01:23.666                 0.0
# ...                                                   ...
# uspgb         2025-06-23 20:26:23.914                 0.0
#               2025-06-23 20:26:23.930                 0.0
#               2025-06-23 20:26:23.947                 0.0
#               2025-06-23 20:26:23.964                 0.0
#               2025-06-23 20:26:23.980                 0.0
#
#                                        acceleration.x_median  \
# participantId time
# 10d83         2025-06-03 12:01:23.600                   0.00
#               2025-06-03 12:01:23.616                   0.00
#               2025-06-03 12:01:23.632                   0.00
#               2025-06-03 12:01:23.649                  -0.05
#               2025-06-03 12:01:23.666                  -0.10
# ...                                                      ...
# uspgb         2025-06-23 20:26:23.914                   0.00
#               2025-06-23 20:26:23.930                   0.00
#               2025-06-23 20:26:23.947                   0.00
#               2025-06-23 20:26:23.964                   0.00
#               2025-06-23 20:26:23.980                   0.00
#
#                                        acceleration.x_skew  ...  \
# participantId time                                          ...
# 10d83         2025-06-03 12:01:23.600                  NaN  ...
#               2025-06-03 12:01:23.616                  NaN  ...
#               2025-06-03 12:01:23.632            -1.732051  ...
#               2025-06-03 12:01:23.649             0.000000  ...
#               2025-06-03 12:01:23.666             0.608581  ...
# ...                                                    ...  ...
# uspgb         2025-06-23 20:26:23.914             0.000000  ...
#               2025-06-23 20:26:23.930             0.000000  ...
#               2025-06-23 20:26:23.947             0.000000  ...
#               2025-06-23 20:26:23.964             0.000000  ...
#               2025-06-23 20:26:23.980             0.000000  ...
#
#                                        rotationRate.gamma_kurt  \
# participantId time
# 10d83         2025-06-03 12:01:23.600                      NaN
#               2025-06-03 12:01:23.616                      NaN
#               2025-06-03 12:01:23.632                      NaN
#               2025-06-03 12:01:23.649                 3.504056
#               2025-06-03 12:01:23.666                -3.258074
# ...                                                        ...
# uspgb         2025-06-23 20:26:23.914                -2.050736
#               2025-06-23 20:26:23.930                -2.039553
#               2025-06-23 20:26:23.947                -2.026191
#               2025-06-23 20:26:23.964                -1.991361
#               2025-06-23 20:26:23.980                -1.972203
#
#                                        rotationRate.gamma_rms  \
# participantId time
# 10d83         2025-06-03 12:01:23.600                0.900000
#               2025-06-03 12:01:23.616                0.900000
#               2025-06-03 12:01:23.632                0.838650
#               2025-06-03 12:01:23.649                0.753326
#               2025-06-03 12:01:23.666                0.697137
# ...                                                       ...
# uspgb         2025-06-23 20:26:23.914                0.068313
#               2025-06-23 20:26:23.930                0.067751
#               2025-06-23 20:26:23.947                0.067082
#               2025-06-23 20:26:23.964                0.065828
#               2025-06-23 20:26:23.980                0.065286
#
#                                        acceleration.magnitude_mean  \
# participantId time
# 10d83         2025-06-03 12:01:23.600                     0.200000
#               2025-06-03 12:01:23.616                     0.150000
#               2025-06-03 12:01:23.632                     0.147140
#               2025-06-03 12:01:23.649                     0.145711
#               2025-06-03 12:01:23.666                     0.144853
# ...                                                            ...
# uspgb         2025-06-23 20:26:23.914                     0.200000
#               2025-06-23 20:26:23.930                     0.200000
#               2025-06-23 20:26:23.947                     0.200000
#               2025-06-23 20:26:23.964                     0.200000
#               2025-06-23 20:26:23.980                     0.200000
#
#                                        acceleration.magnitude_var  \
# participantId time
# 10d83         2025-06-03 12:01:23.600                         NaN
#               2025-06-03 12:01:23.616                    0.005000
#               2025-06-03 12:01:23.632                    0.002525
#               2025-06-03 12:01:23.649                    0.001691
#               2025-06-03 12:01:23.666                    0.001272
# ...                                                           ...
# uspgb         2025-06-23 20:26:23.914                    0.000000
#               2025-06-23 20:26:23.930                    0.000000
#               2025-06-23 20:26:23.947                    0.000000
#               2025-06-23 20:26:23.964                    0.000000
#               2025-06-23 20:26:23.980                    0.000000
#
#                                        acceleration.magnitude_min  \
# participantId time
# 10d83         2025-06-03 12:01:23.600                         0.2
#               2025-06-03 12:01:23.616                         0.1
#               2025-06-03 12:01:23.632                         0.1
#               2025-06-03 12:01:23.649                         0.1
#               2025-06-03 12:01:23.666                         0.1
# ...                                                           ...
# uspgb         2025-06-23 20:26:23.914                         0.2
#               2025-06-23 20:26:23.930                         0.2
#               2025-06-23 20:26:23.947                         0.2
#               2025-06-23 20:26:23.964                         0.2
#               2025-06-23 20:26:23.980                         0.2
#
#                                        acceleration.magnitude_max  \
# participantId time
# 10d83         2025-06-03 12:01:23.600                         0.2
#               2025-06-03 12:01:23.616                         0.2
#               2025-06-03 12:01:23.632                         0.2
#               2025-06-03 12:01:23.649                         0.2
#               2025-06-03 12:01:23.666                         0.2
# ...                                                           ...
# uspgb         2025-06-23 20:26:23.914                         0.2
#               2025-06-23 20:26:23.930                         0.2
#               2025-06-23 20:26:23.947                         0.2
#               2025-06-23 20:26:23.964                         0.2
#               2025-06-23 20:26:23.980                         0.2
#
#                                        acceleration.magnitude_median  \
# participantId time
# 10d83         2025-06-03 12:01:23.600                       0.200000
#               2025-06-03 12:01:23.616                       0.150000
#               2025-06-03 12:01:23.632                       0.141421
#               2025-06-03 12:01:23.649                       0.141421
#               2025-06-03 12:01:23.666                       0.141421
# ...                                                              ...
# uspgb         2025-06-23 20:26:23.914                       0.200000
#               2025-06-23 20:26:23.930                       0.200000
#               2025-06-23 20:26:23.947                       0.200000
#               2025-06-23 20:26:23.964                       0.200000
#               2025-06-23 20:26:23.980                       0.200000
#
#                                        acceleration.magnitude_skew  \
# participantId time
# 10d83         2025-06-03 12:01:23.600                          NaN
#               2025-06-03 12:01:23.616                          NaN
#               2025-06-03 12:01:23.632                     0.505575
#               2025-06-03 12:01:23.649                     0.616733
#               2025-06-03 12:01:23.666                     0.710445
# ...                                                            ...
# uspgb         2025-06-23 20:26:23.914                     0.000000
#               2025-06-23 20:26:23.930                     0.000000
#               2025-06-23 20:26:23.947                     0.000000
#               2025-06-23 20:26:23.964                     0.000000
#               2025-06-23 20:26:23.980                     0.000000
#
#                                        acceleration.magnitude_kurt  \
# participantId time
# 10d83         2025-06-03 12:01:23.600                          NaN
#               2025-06-03 12:01:23.616                          NaN
#               2025-06-03 12:01:23.632                          NaN
#               2025-06-03 12:01:23.649                     1.712843
#               2025-06-03 12:01:23.666                     2.271267
# ...                                                            ...
# uspgb         2025-06-23 20:26:23.914                    -3.000000
#               2025-06-23 20:26:23.930                    -3.000000
#               2025-06-23 20:26:23.947                    -3.000000
#               2025-06-23 20:26:23.964                    -3.000000
#               2025-06-23 20:26:23.980                    -3.000000
#
#                                        acceleration.magnitude_rms
# participantId time
# 10d83         2025-06-03 12:01:23.600                    0.200000
#               2025-06-03 12:01:23.616                    0.158114
#               2025-06-03 12:01:23.632                    0.152753
#               2025-06-03 12:01:23.649                    0.150000
#               2025-06-03 12:01:23.666                    0.148324
# ...                                                           ...
# uspgb         2025-06-23 20:26:23.914                    0.200000
#               2025-06-23 20:26:23.930                    0.200000
#               2025-06-23 20:26:23.947                    0.200000
#               2025-06-23 20:26:23.964                    0.200000
#               2025-06-23 20:26:23.980                    0.200000
#
# [114351 rows x 84 columns]

# %%
# Only keep rolling time windows with at least 60 data points
df_encoded_4 = df_encoded_3[df_encoded_3.activity_count >= 60 ].copy()

# Remove time from Index
df_encoded_4.index = df_encoded_4.index.droplevel(1)

# Format participantId as column 
df_encoded_4 = df_encoded_4.reset_index()
df_encoded_4
# Out:
#        participantId  activity  activity_count  browser_Chrome  \
# 0              10d83       0.0            60.0             1.0
# 1              10d83       0.0            61.0             1.0
# 2              10d83       0.0            60.0             1.0
# 3              10d83       0.0            60.0             1.0
# 4              10d83       0.0            60.0             1.0
# ...              ...       ...             ...             ...
# 108191         uspgb       0.0            60.0             1.0
# 108192         uspgb       0.0            61.0             1.0
# 108193         uspgb       0.0            60.0             1.0
# 108194         uspgb       0.0            60.0             1.0
# 108195         uspgb       0.0            61.0             1.0
#
#         browser_Safari  acceleration.x_mean  acceleration.x_var  \
# 0                  0.0             0.008333            0.011624
# 1                  0.0             0.008197            0.011432
# 2                  0.0             0.008333            0.011624
# 3                  0.0             0.011667            0.011556
# 4                  0.0             0.015000            0.011466
# ...                ...                  ...                 ...
# 108191             0.0             0.000000            0.000000
# 108192             0.0             0.000000            0.000000
# 108193             0.0             0.000000            0.000000
# 108194             0.0             0.000000            0.000000
# 108195             0.0             0.000000            0.000000
#
#         acceleration.x_min  acceleration.x_max  acceleration.x_median  ...  \
# 0                     -0.2                 0.3                    0.0  ...
# 1                     -0.2                 0.3                    0.0  ...
# 2                     -0.2                 0.3                    0.0  ...
# 3                     -0.2                 0.3                    0.0  ...
# 4                     -0.2                 0.3                    0.0  ...
# ...                    ...                 ...                    ...  ...
# 108191                 0.0                 0.0                    0.0  ...
# 108192                 0.0                 0.0                    0.0  ...
# 108193                 0.0                 0.0                    0.0  ...
# 108194                 0.0                 0.0                    0.0  ...
# 108195                 0.0                 0.0                    0.0  ...
#
#         rotationRate.gamma_kurt  rotationRate.gamma_rms  \
# 0                      1.689329                0.947365
# 1                      1.771144                0.939916
# 2                      1.867892                0.933720
# 3                      1.885031                0.932559
# 4                      1.703081                0.953764
# ...                         ...                     ...
# 108191                -2.050736                0.068313
# 108192                -2.039553                0.067751
# 108193                -2.026191                0.067082
# 108194                -1.991361                0.065828
# 108195                -1.972203                0.065286
#
#         acceleration.magnitude_mean  acceleration.magnitude_var  \
# 0                          0.190612                    0.014577
# 1                          0.189805                    0.014373
# 2                          0.189635                    0.014615
# 3                          0.188945                    0.014712
# 4                          0.188945                    0.014712
# ...                             ...                         ...
# 108191                     0.200000                    0.000000
# 108192                     0.200000                    0.000000
# 108193                     0.200000                    0.000000
# 108194                     0.200000                    0.000000
# 108195                     0.200000                    0.000000
#
#         acceleration.magnitude_min  acceleration.magnitude_max  \
# 0                              0.0                         0.5
# 1                              0.0                         0.5
# 2                              0.0                         0.5
# 3                              0.0                         0.5
# 4                              0.0                         0.5
# ...                            ...                         ...
# 108191                         0.2                         0.2
# 108192                         0.2                         0.2
# 108193                         0.2                         0.2
# 108194                         0.2                         0.2
# 108195                         0.2                         0.2
#
#         acceleration.magnitude_median  acceleration.magnitude_skew  \
# 0                            0.186603                     0.189219
# 1                            0.173205                     0.209592
# 2                            0.173205                     0.212345
# 3                            0.173205                     0.221952
# 4                            0.173205                     0.221952
# ...                               ...                          ...
# 108191                       0.200000                     0.000000
# 108192                       0.200000                     0.000000
# 108193                       0.200000                     0.000000
# 108194                       0.200000                     0.000000
# 108195                       0.200000                     0.000000
#
#         acceleration.magnitude_kurt  acceleration.magnitude_rms
# 0                         -0.347866                    0.225093
# 1                         -0.311795                    0.223973
# 2                         -0.355254                    0.224351
# 3                         -0.381514                    0.223979
# 4                         -0.381514                    0.223979
# ...                             ...                         ...
# 108191                    -3.000000                    0.200000
# 108192                    -3.000000                    0.200000
# 108193                    -3.000000                    0.200000
# 108194                    -3.000000                    0.200000
# 108195                    -3.000000                    0.200000
#
# [108196 rows x 85 columns]

# %%
# Drop NA values (0 NA values, excluding recordings with less than 60 points already eliminated all NA values)
df_encoded_5 = df_encoded_4.dropna()

# Convert acitivity column back to labels (why convert it in the first place?)
df_encoded_5.activity = df_encoded_5.activity.apply(lambda x: labels[int(x)])

# %%
# Store features
pickle.dump(df_encoded_5,open("../features.pkl","wb"))

# %%
# Activity distribution before undersampling
df_encoded_5.groupby('activity').size()
# Out:
# activity
# sitting     57102
# standing     7610
# walking     43484
# dtype: int64

# %%
from imblearn.under_sampling import RandomUnderSampler

# Undersample majority classes to get balanced distribution
X, y = RandomUnderSampler().fit_resample(df_encoded_5.drop(columns=["activity"]), df_encoded_5.activity)

# For Leave one group out
groups=X.participantId

# Drop participantId
X.drop(columns=["participantId"], inplace=True)

# %%
# Activity distribution after undersampling
pd.concat([X, y], axis=1).groupby('activity').size()
# Out:
# activity
# sitting     7610
# standing    7610
# walking     7610
# dtype: int64

# %%
import seaborn as sns

# Define the base DataFrame
df_balanced = X[[col for col in X.columns if col.startswith(("acceleration", "rotationRate"))]].copy()
df_balanced["activity"] = y

# Number of features per pairplot
chunk_size = 5

# Get list of feature columns (excluding target)
feature_cols = [col for col in df_balanced.columns if col != "activity"]

# Split feature columns into chunks
for i in range(0, len(feature_cols), chunk_size):
    subset = feature_cols[i:i+chunk_size]
    subset_df = df_balanced[subset + ["activity"]]

    # Create the pairplot with some transparency
    g = sns.pairplot(subset_df, hue="activity", diag_kind="kde", plot_kws={'alpha': 0.5})

    # Title and layout
    plot_title = f"Features {i+1} to {min(i+chunk_size, len(feature_cols))}"
    g.fig.suptitle(plot_title, y=1.02)
    plt.tight_layout()

    # Save to file
    filename = f"pairplot_{i+1}_{min(i+chunk_size, len(feature_cols))}.png"
    g.fig.savefig(filename, dpi=300)
    plt.close(g.fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 17
#      14 subset_df = df_balanced[subset + ["activity"]]
#      16 # Create the pairplot with some transparency
# ---> 17 g = sns.pairplot(subset_df, hue="activity", diag_kind="kde", plot_kws={'alpha': 0.5})
#      19 # Title and layout
#      20 plot_title = f"Features {i+1} to {min(i+chunk_size, len(feature_cols))}"
#
# NameError: name 'sns' is not defined

# %% [markdown]
# Perform manual feature selection based on pairplot distributions
#
# Keep only most informative/discriminative features
#
# e.g. acceleration.x_var => strongly separates walking from standing/sitting
#
# e.g. acceleration.x_max => captures extreme values only seen during walking
#
# e.g. acceleration.x_rms => distinct distribution peaks for all three activities

# %%
keep_features = [
    "acceleration.x_var", 
    "acceleration.x_max", 
    "acceleration.x_rms", 
    "acceleration.y_skew", 
    "accelerationIncludingGravity.x_mean", 
    "accelerationIncludingGravity.x_max",
    "accelerationIncludingGravity.y_mean",
    "accelerationIncludingGravity.y_rms",
    "accelerationIncludingGravity.z_var",
    "accelerationIncludingGravity.z_mean",
    "acceleration.magnitude_mean",
    "acceleration.magnitude_rms"
]

# %%
df_selected = X[keep_features]
corr = df_selected.corr()

corr
# Out:
#                                      acceleration.x_var  acceleration.x_max  \
# acceleration.x_var                             1.000000            0.849053
# acceleration.x_max                             0.849053            1.000000
# acceleration.x_rms                             0.864258            0.874158
# acceleration.y_skew                           -0.016403            0.011631
# accelerationIncludingGravity.x_mean            0.323166            0.360985
# accelerationIncludingGravity.x_max             0.669121            0.795239
# accelerationIncludingGravity.y_mean           -0.149311           -0.139641
# accelerationIncludingGravity.y_rms            -0.037332            0.050769
# accelerationIncludingGravity.z_var             0.631715            0.548359
# accelerationIncludingGravity.z_mean           -0.276496           -0.166214
# acceleration.magnitude_mean                    0.743490            0.745016
# acceleration.magnitude_rms                     0.751609            0.768728
#
#                                      acceleration.x_rms  acceleration.y_skew  \
# acceleration.x_var                             0.864258            -0.016403
# acceleration.x_max                             0.874158             0.011631
# acceleration.x_rms                             1.000000            -0.056499
# acceleration.y_skew                           -0.056499             1.000000
# accelerationIncludingGravity.x_mean            0.335155             0.040275
# accelerationIncludingGravity.x_max             0.730312             0.023086
# accelerationIncludingGravity.y_mean           -0.096398            -0.064597
# accelerationIncludingGravity.y_rms             0.012748             0.060015
# accelerationIncludingGravity.z_var             0.645760            -0.034576
# accelerationIncludingGravity.z_mean           -0.165169            -0.044096
# acceleration.magnitude_mean                    0.901511            -0.040126
# acceleration.magnitude_rms                     0.915511            -0.053111
#
#                                      accelerationIncludingGravity.x_mean  \
# acceleration.x_var                                              0.323166
# acceleration.x_max                                              0.360985
# acceleration.x_rms                                              0.335155
# acceleration.y_skew                                             0.040275
# accelerationIncludingGravity.x_mean                             1.000000
# accelerationIncludingGravity.x_max                              0.817738
# accelerationIncludingGravity.y_mean                            -0.297049
# accelerationIncludingGravity.y_rms                              0.176672
# accelerationIncludingGravity.z_var                              0.122368
# accelerationIncludingGravity.z_mean                            -0.055215
# acceleration.magnitude_mean                                     0.237680
# acceleration.magnitude_rms                                      0.250919
#
#                                      accelerationIncludingGravity.x_max  \
# acceleration.x_var                                             0.669121
# acceleration.x_max                                             0.795239
# acceleration.x_rms                                             0.730312
# acceleration.y_skew                                            0.023086
# accelerationIncludingGravity.x_mean                            0.817738
# accelerationIncludingGravity.x_max                             1.000000
# accelerationIncludingGravity.y_mean                           -0.269503
# accelerationIncludingGravity.y_rms                             0.150453
# accelerationIncludingGravity.z_var                             0.402423
# accelerationIncludingGravity.z_mean                           -0.108703
# acceleration.magnitude_mean                                    0.599499
# acceleration.magnitude_rms                                     0.625545
#
#                                      accelerationIncludingGravity.y_mean  \
# acceleration.x_var                                             -0.149311
# acceleration.x_max                                             -0.139641
# acceleration.x_rms                                             -0.096398
# acceleration.y_skew                                            -0.064597
# accelerationIncludingGravity.x_mean                            -0.297049
# accelerationIncludingGravity.x_max                             -0.269503
# accelerationIncludingGravity.y_mean                             1.000000
# accelerationIncludingGravity.y_rms                              0.073595
# accelerationIncludingGravity.z_var                             -0.135778
# accelerationIncludingGravity.z_mean                             0.499806
# acceleration.magnitude_mean                                    -0.088016
# acceleration.magnitude_rms                                     -0.092603
#
#                                      accelerationIncludingGravity.y_rms  \
# acceleration.x_var                                            -0.037332
# acceleration.x_max                                             0.050769
# acceleration.x_rms                                             0.012748
# acceleration.y_skew                                            0.060015
# accelerationIncludingGravity.x_mean                            0.176672
# accelerationIncludingGravity.x_max                             0.150453
# accelerationIncludingGravity.y_mean                            0.073595
# accelerationIncludingGravity.y_rms                             1.000000
# accelerationIncludingGravity.z_var                            -0.077225
# accelerationIncludingGravity.z_mean                           -0.065934
# acceleration.magnitude_mean                                   -0.047559
# acceleration.magnitude_rms                                    -0.040767
#
#                                      accelerationIncludingGravity.z_var  \
# acceleration.x_var                                             0.631715
# acceleration.x_max                                             0.548359
# acceleration.x_rms                                             0.645760
# acceleration.y_skew                                           -0.034576
# accelerationIncludingGravity.x_mean                            0.122368
# accelerationIncludingGravity.x_max                             0.402423
# accelerationIncludingGravity.y_mean                           -0.135778
# accelerationIncludingGravity.y_rms                            -0.077225
# accelerationIncludingGravity.z_var                             1.000000
# accelerationIncludingGravity.z_mean                           -0.372985
# acceleration.magnitude_mean                                    0.840671
# acceleration.magnitude_rms                                     0.837409
#
#                                      accelerationIncludingGravity.z_mean  \
# acceleration.x_var                                             -0.276496
# acceleration.x_max                                             -0.166214
# acceleration.x_rms                                             -0.165169
# acceleration.y_skew                                            -0.044096
# accelerationIncludingGravity.x_mean                            -0.055215
# accelerationIncludingGravity.x_max                             -0.108703
# accelerationIncludingGravity.y_mean                             0.499806
# accelerationIncludingGravity.y_rms                             -0.065934
# accelerationIncludingGravity.z_var                             -0.372985
# accelerationIncludingGravity.z_mean                             1.000000
# acceleration.magnitude_mean                                    -0.236270
# acceleration.magnitude_rms                                     -0.222708
#
#                                      acceleration.magnitude_mean  \
# acceleration.x_var                                      0.743490
# acceleration.x_max                                      0.745016
# acceleration.x_rms                                      0.901511
# acceleration.y_skew                                    -0.040126
# accelerationIncludingGravity.x_mean                     0.237680
# accelerationIncludingGravity.x_max                      0.599499
# accelerationIncludingGravity.y_mean                    -0.088016
# accelerationIncludingGravity.y_rms                     -0.047559
# accelerationIncludingGravity.z_var                      0.840671
# accelerationIncludingGravity.z_mean                    -0.236270
# acceleration.magnitude_mean                             1.000000
# acceleration.magnitude_rms                              0.994447
#
#                                      acceleration.magnitude_rms
# acceleration.x_var                                     0.751609
# acceleration.x_max                                     0.768728
# acceleration.x_rms                                     0.915511
# acceleration.y_skew                                   -0.053111
# accelerationIncludingGravity.x_mean                    0.250919
# accelerationIncludingGravity.x_max                     0.625545
# accelerationIncludingGravity.y_mean                   -0.092603
# accelerationIncludingGravity.y_rms                    -0.040767
# accelerationIncludingGravity.z_var                     0.837409
# accelerationIncludingGravity.z_mean                   -0.222708
# acceleration.magnitude_mean                            0.994447
# acceleration.magnitude_rms                             1.000000

# %% [markdown]
# acceleration.x_rms, acceleration.magnitude_mean & acceleration.magnitude_rms have very high correlation
#
# => Keep only acceleration.magnitude_rms

# %%
keep_features.remove("acceleration.x_rms")
keep_features.remove("acceleration.magnitude_mean")

# %%
import seaborn as sns

# Only keep acceleration features
df_balanced = X[[col for col in X.columns if col.startswith(("acceleration.x_", "b"))]].copy()
df_balanced["activity"] = y

# Creates scatter plots for all numeric variables, histograms on diagonal axis and colors points based on acitivity (hue=activity) 
sns.pairplot(df_balanced, hue="activity")

# %%
# ...

# %%
df_encoded_5.columns
# Out:
# Index(['participantId', 'activity', 'activity_count', 'browser_Chrome',
#        'browser_Safari', 'acceleration.x_mean', 'acceleration.x_var',
#        'acceleration.x_min', 'acceleration.x_max', 'acceleration.x_median',
#        'acceleration.x_skew', 'acceleration.x_kurt', 'acceleration.x_rms',
#        'acceleration.y_mean', 'acceleration.y_var', 'acceleration.y_min',
#        'acceleration.y_max', 'acceleration.y_median', 'acceleration.y_skew',
#        'acceleration.y_kurt', 'acceleration.y_rms', 'acceleration.z_mean',
#        'acceleration.z_var', 'acceleration.z_min', 'acceleration.z_max',
#        'acceleration.z_median', 'acceleration.z_skew', 'acceleration.z_kurt',
#        'acceleration.z_rms', 'accelerationIncludingGravity.x_mean',
#        'accelerationIncludingGravity.x_var',
#        'accelerationIncludingGravity.x_min',
#        'accelerationIncludingGravity.x_max',
#        'accelerationIncludingGravity.x_median',
#        'accelerationIncludingGravity.x_skew',
#        'accelerationIncludingGravity.x_kurt',
#        'accelerationIncludingGravity.x_rms',
#        'accelerationIncludingGravity.y_mean',
#        'accelerationIncludingGravity.y_var',
#        'accelerationIncludingGravity.y_min',
#        'accelerationIncludingGravity.y_max',
#        'accelerationIncludingGravity.y_median',
#        'accelerationIncludingGravity.y_skew',
#        'accelerationIncludingGravity.y_kurt',
#        'accelerationIncludingGravity.y_rms',
#        'accelerationIncludingGravity.z_mean',
#        'accelerationIncludingGravity.z_var',
#        'accelerationIncludingGravity.z_min',
#        'accelerationIncludingGravity.z_max',
#        'accelerationIncludingGravity.z_median',
#        'accelerationIncludingGravity.z_skew',
#        'accelerationIncludingGravity.z_kurt',
#        'accelerationIncludingGravity.z_rms', 'rotationRate.alpha_mean',
#        'rotationRate.alpha_var', 'rotationRate.alpha_min',
#        'rotationRate.alpha_max', 'rotationRate.alpha_median',
#        'rotationRate.alpha_skew', 'rotationRate.alpha_kurt',
#        'rotationRate.alpha_rms', 'rotationRate.beta_mean',
#        'rotationRate.beta_var', 'rotationRate.beta_min',
#        'rotationRate.beta_max', 'rotationRate.beta_median',
#        'rotationRate.beta_skew', 'rotationRate.beta_kurt',
#        'rotationRate.beta_rms', 'rotationRate.gamma_mean',
#        'rotationRate.gamma_var', 'rotationRate.gamma_min',
#        'rotationRate.gamma_max', 'rotationRate.gamma_median',
#        'rotationRate.gamma_skew', 'rotationRate.gamma_kurt',
#        'rotationRate.gamma_rms', 'acceleration.magnitude_mean',
#        'acceleration.magnitude_var', 'acceleration.magnitude_min',
#        'acceleration.magnitude_max', 'acceleration.magnitude_median',
#        'acceleration.magnitude_skew', 'acceleration.magnitude_kurt',
#        'acceleration.magnitude_rms'],
#       dtype='object')

# %%
import warnings
from sklearn.model_selection import cross_validate,LeaveOneGroupOut
from sklearn.tree import DecisionTreeClassifier

warnings.filterwarnings('ignore')

# Define metrics for cross validation
classifier_metrics = [
    "accuracy", "balanced_accuracy", "precision_macro", "recall_macro",
    "f1_macro"
]

# Leave One Group Out CV
scores=pd.DataFrame(cross_validate(DecisionTreeClassifier(), X, y, cv=LeaveOneGroupOut(), groups=groups, scoring=classifier_metrics , verbose = True))

scores
# Out:
#     fit_time  score_time  test_accuracy  test_balanced_accuracy  \
# 0   0.514926    0.021039       0.483308                0.671106
# 1   0.401823    0.062192       0.511920                0.499396
# 2   0.521779    0.017277       1.000000                1.000000
# 3   0.563406    0.005249       0.083969                0.083969
# 4   0.553015    0.013675       0.000000                0.000000
# 5   0.513901    0.016404       0.015748                0.015748
# 6   0.572814    0.008846       1.000000                1.000000
# 7   0.570003    0.005231       0.833333                0.833333
# 8   0.577822    0.008182       1.000000                1.000000
# 9   0.578866    0.007203       1.000000                1.000000
# 10  0.442092    0.014374       0.900865                0.876778
# 11  0.514627    0.015697       0.914123                0.914123
# 12  0.571894    0.006919       0.933610                0.933610
# 13  0.575961    0.038141       0.286420                0.303232
# 14  0.642736    0.005769       0.166667                0.166667
# 15  0.414130    0.021715       0.756675                0.756675
# 16  0.557356    0.008965       0.896721                0.896721
# 17  0.584614    0.005474       1.000000                1.000000
#
#     test_precision_macro  test_recall_macro  test_f1_macro
# 0               0.593046           0.671106       0.508270
# 1               0.170772           0.332931       0.225749
# 2               1.000000           1.000000       1.000000
# 3               0.333333           0.027990       0.051643
# 4               0.000000           0.000000       0.000000
# 5               0.333333           0.005249       0.010336
# 6               1.000000           1.000000       1.000000
# 7               0.500000           0.416667       0.454545
# 8               1.000000           1.000000       1.000000
# 9               1.000000           1.000000       1.000000
# 10              0.919931           0.876778       0.893621
# 11              0.333333           0.304708       0.318378
# 12              0.500000           0.466805       0.482833
# 13              0.431639           0.202154       0.272441
# 14              0.333333           0.055556       0.095238
# 15              0.500000           0.378337       0.430743
# 16              0.333333           0.298907       0.315183
# 17              1.000000           1.000000       1.000000

# %%
scores.mean()
# Out:
# fit_time                  0.537320
# score_time                0.015686
# test_accuracy             0.654631
# test_balanced_accuracy    0.663964
# test_precision_macro      0.571225
# test_recall_macro         0.502066
# test_f1_macro             0.503277
# dtype: float64

# %%
from sklearn.feature_selection import RFECV
from sklearn.model_selection import GroupKFold

# Recursive feature elimination with CV
# Fitting DecisionTree and removing least important feature at each step
rfecv = RFECV(estimator=DecisionTreeClassifier(), cv=GroupKFold(n_splits=5), step=1 , verbose=1, scoring='f1_macro').fit(X,y,groups=groups)
# Out:
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# Fitting estimator with 48 features.
# Fitting estimator with 47 features.
# Fitting estimator with 46 features.
# Fitting estimator with 45 features.
# Fitting estimator with 44 features.
# Fitting estimator with 43 features.
# Fitting estimator with 42 features.
# Fitting estimator with 41 features.
# Fitting estimator with 40 features.
# Fitting estimator with 39 features.
# Fitting estimator with 38 features.
# Fitting estimator with 37 features.
# Fitting estimator with 36 features.
# Fitting estimator with 35 features.
# Fitting estimator with 34 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.

# %%
# Print the optimal number of features and their indices

print("Optimal number of features : %d" % rfecv.n_features_)
print("Selected features : %s" % rfecv.support_)

# 1 -> Selected, >1 -> Not selected, the lower the number the later during the process it got eliminated
print("Feature ranking : %s" % rfecv.ranking_)
# Out:
# Optimal number of features : 5
# Selected features : [ True False False False False False False False False False False False
#  False False False  True False False False False  True False False False
#  False False False False False False False  True False False  True False
#  False False False False False False False False False False False False]
# Feature ranking : [ 1 20 44 13 43 24 17 31  6 10 26  7 11 29  3  1 42 18 41 39  1 12  5 27
#  35  4  2 19 15 34  8  1 40 28  1  9 38 33 37 36 25 16 30 32 21 22 23 14]

# %%
cv_results = pd.DataFrame(rfecv.cv_results_)
cv_results
# Out:
#     mean_test_score  std_test_score  split0_test_score  split1_test_score  \
# 0          0.425514        0.078097           0.341810           0.447712
# 1          0.337470        0.114343           0.226051           0.276703
# 2          0.368411        0.184766           0.226051           0.173045
# 3          0.395473        0.194702           0.226051           0.163373
# 4          0.472641        0.272940           0.339076           0.101702
# 5          0.395845        0.241708           0.225930           0.114481
# 6          0.453544        0.200023           0.225839           0.336622
# 7          0.394764        0.119218           0.225839           0.314856
# 8          0.447417        0.177412           0.225839           0.359193
# 9          0.440843        0.171942           0.225839           0.349418
# 10         0.433340        0.173050           0.225839           0.312444
# 11         0.410519        0.200589           0.225930           0.187582
# 12         0.382287        0.153977           0.225839           0.183719
# 13         0.407591        0.211021           0.225930           0.148475
# 14         0.403505        0.109754           0.225930           0.347352
# 15         0.401568        0.110887           0.225749           0.329843
# 16         0.403682        0.114575           0.225839           0.339783
# 17         0.408264        0.113908           0.225839           0.356679
# 18         0.406619        0.111080           0.225839           0.346383
# 19         0.374723        0.151308           0.225749           0.174119
# 20         0.368782        0.142166           0.225839           0.173932
# 21         0.372837        0.147813           0.225839           0.177615
# 22         0.364627        0.151618           0.225839           0.152170
# 23         0.372515        0.149517           0.225839           0.173727
# 24         0.368997        0.149532           0.225749           0.163522
# 25         0.374740        0.135490           0.225839           0.206822
# 26         0.367558        0.148798           0.225749           0.164171
# 27         0.370251        0.148917           0.225930           0.171917
# 28         0.366741        0.146466           0.225839           0.166589
# 29         0.362625        0.153179           0.225839           0.144085
# 30         0.364857        0.140289           0.225749           0.178380
# 31         0.361498        0.150368           0.225930           0.143915
# 32         0.364288        0.139291           0.225839           0.179160
# 33         0.366846        0.140775           0.225749           0.176271
# 34         0.375298        0.147005           0.225930           0.173847
# 35         0.376554        0.153023           0.225839           0.167345
# 36         0.378444        0.156249           0.225749           0.159269
# 37         0.374466        0.140130           0.225839           0.187624
# 38         0.371707        0.151366           0.225749           0.155629
# 39         0.363973        0.140123           0.225839           0.177286
# 40         0.362281        0.140563           0.225749           0.172346
# 41         0.377168        0.146496           0.225930           0.174580
# 42         0.373685        0.153518           0.225930           0.152810
# 43         0.362595        0.157973           0.225749           0.139031
# 44         0.367127        0.143866           0.225839           0.181438
# 45         0.366253        0.146111           0.225749           0.172643
# 46         0.362774        0.145978           0.225839           0.157562
# 47         0.374384        0.149215           0.225749           0.164229
#
#     split2_test_score  split3_test_score  split4_test_score  n_features
# 0            0.328270           0.483221           0.526557           1
# 1            0.260097           0.384346           0.540154           2
# 2            0.700629           0.340552           0.401776           3
# 3            0.578881           0.661922           0.347138           4
# 4            0.813592           0.763493           0.345344           5
# 5            0.808949           0.494593           0.335270           6
# 6            0.816589           0.480070           0.408601           7
# 7            0.576847           0.447654           0.408624           8
# 8            0.764045           0.433568           0.454441           9
# 9            0.746166           0.438957           0.443836          10
# 10           0.736086           0.440001           0.452327          11
# 11           0.749674           0.440089           0.449320          12
# 12           0.588423           0.479804           0.433650          13
# 13           0.749166           0.478571           0.435812          14
# 14           0.543026           0.479241           0.421978          15
# 15           0.535675           0.480691           0.435883          16
# 16           0.556554           0.484221           0.412012          17
# 17           0.563044           0.478209           0.417548          18
# 18           0.544382           0.481426           0.435065          19
# 19           0.569996           0.483486           0.420262          20
# 20           0.530797           0.478575           0.434767          21
# 21           0.562801           0.479348           0.418584          22
# 22           0.551272           0.479767           0.414087          23
# 23           0.565323           0.479819           0.417868          24
# 24           0.552848           0.480301           0.422566          25
# 25           0.543557           0.480107           0.417372          26
# 26           0.552705           0.480296           0.414867          27
# 27           0.564239           0.476475           0.412696          28
# 28           0.545443           0.481343           0.414491          29
# 29           0.547692           0.480203           0.415306          30
# 30           0.535909           0.481372           0.402873          31
# 31           0.532036           0.480862           0.424747          32
# 32           0.532219           0.482462           0.401761          33
# 33           0.530805           0.481643           0.419761          34
# 34           0.541376           0.483674           0.451662          35
# 35           0.564288           0.478899           0.446400          36
# 36           0.557577           0.479990           0.469634          37
# 37           0.532219           0.479200           0.447449          38
# 38           0.534995           0.479797           0.462365          39
# 39           0.535842           0.479197           0.401701          40
# 40           0.532045           0.479206           0.402059          41
# 41           0.528327           0.479987           0.477018          42
# 42           0.532219           0.481726           0.475739          43
# 43           0.563696           0.480585           0.403914          44
# 44           0.555993           0.479987           0.392375          45
# 45           0.554400           0.480854           0.397618          46
# 46           0.532691           0.480362           0.417416          47
# 47           0.530617           0.484166           0.467157          48

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Mean test accuracy")
plt.errorbar(
    x=cv_results.index,
    y=cv_results["mean_test_score"],
    yerr=cv_results["std_test_score"],
)
plt.title("Recursive Feature Elimination")
plt.show()

# %%
df_feature = pd.concat([df_encoded_5.participantId,df_encoded_5.activity,df_encoded_5[rfecv.get_feature_names_out(X.columns)]],axis=1).dropna()
df_feature
# Out:
#        participantId activity  activity_count  acceleration.z_min  \
# 0              10d83  sitting            60.0                -0.3
# 1              10d83  sitting            61.0                -0.3
# 2              10d83  sitting            60.0                -0.3
# 3              10d83  sitting            60.0                -0.3
# 4              10d83  sitting            60.0                -0.3
# ...              ...      ...             ...                 ...
# 108191         uspgb  sitting            60.0                -0.2
# 108192         uspgb  sitting            61.0                -0.2
# 108193         uspgb  sitting            60.0                -0.2
# 108194         uspgb  sitting            60.0                -0.2
# 108195         uspgb  sitting            61.0                -0.2
#
#         accelerationIncludingGravity.x_min  \
# 0                                     -0.9
# 1                                     -0.9
# 2                                     -0.9
# 3                                     -0.9
# 4                                     -0.9
# ...                                    ...
# 108191                                -0.1
# 108192                                -0.1
# 108193                                -0.1
# 108194                                -0.1
# 108195                                -0.1
#
#         accelerationIncludingGravity.z_max  rotationRate.alpha_var
# 0                                      5.6                4.486879
# 1                                      5.6                4.555568
# 2                                      5.6                4.674735
# 3                                      5.6                4.801186
# 4                                      5.6                4.811127
# ...                                    ...                     ...
# 108191                                 9.6                0.194404
# 108192                                 9.6                0.191525
# 108193                                 9.6                0.176497
# 108194                                 9.6                0.168768
# 108195                                 9.6                0.166448
#
# [108196 rows x 7 columns]
